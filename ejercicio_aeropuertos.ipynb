# %%
import pandas as pd

# %%
aeropuerto = pd.read_csv('/Users/gisselaaviles/anaconda3/envs/samsungIA/airports.csv')
aeropuerto
# Out:
#            id    ident           type                       name  \
# 0        6523      00A       heliport          Total RF Heliport
# 1      323361     00AA  small_airport       Aero B Ranch Airport
# 2        6524     00AK  small_airport               Lowell Field
# 3        6525     00AL  small_airport               Epps Airpark
# 4      506791     00AN  small_airport       Katmai Lodge Airport
# ...       ...      ...            ...                        ...
# 76751   46378  ZZ-0001       heliport            Sealand Helipad
# 76752  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 76753  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 76754  342102     ZZZW         closed     Scandium City Heliport
# 76755  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070985     -74.933689          11.0       NaN          US
# ...

# %%
countries = pd.read_csv('/Users/gisselaaviles/anaconda3/envs/samsungIA/countries.csv')
countries
# Out:
#          id code                           name continent  \
# 0    302672   AD                        Andorra        EU
# 1    302618   AE           United Arab Emirates        AS
# 2    302619   AF                    Afghanistan        AS
# 3    302722   AG            Antigua and Barbuda       NaN
# 4    302723   AI                       Anguilla       NaN
# ..      ...  ...                            ...       ...
# 243  302609   YT                        Mayotte        AF
# 244  302610   ZA                   South Africa        AF
# 245  302611   ZM                         Zambia        AF
# 246  302612   ZW                       Zimbabwe        AF
# 247  302613   ZZ  Unknown or unassigned country        AF
#
#                                         wikipedia_link  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2            https://en.wikipedia.org/wiki/Afghanistan
# ...

# %%
aeropuerto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76756 entries, 0 to 76755
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 76756 non-null  int64
#  1   ident              76756 non-null  object
#  2   type               76756 non-null  object
#  3   name               76756 non-null  object
#  4   latitude_deg       76756 non-null  float64
#  5   longitude_deg      76756 non-null  float64
#  6   elevation_ft       62397 non-null  float64
#  7   continent          39710 non-null  object
#  8   iso_country        76497 non-null  object
#  9   iso_region         76756 non-null  object
#  10  municipality       71805 non-null  object
#  11  scheduled_service  76756 non-null  object
#  12  gps_code           41615 non-null  object
#  13  iata_code          8898 non-null   object
#  14  local_code         32832 non-null  object
#  15  home_link          3711 non-null   object
# ...

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              248 non-null    int64
#  1   code            247 non-null    object
#  2   name            248 non-null    object
#  3   continent       207 non-null    object
#  4   wikipedia_link  248 non-null    object
#  5   keywords        232 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 11.8+ KB

# %%
pd.concat([aeropuerto,countries],axis = 1)
# Out:
#            id    ident           type                       name  \
# 0        6523      00A       heliport          Total RF Heliport
# 1      323361     00AA  small_airport       Aero B Ranch Airport
# 2        6524     00AK  small_airport               Lowell Field
# 3        6525     00AL  small_airport               Epps Airpark
# 4      506791     00AN  small_airport       Katmai Lodge Airport
# ...       ...      ...            ...                        ...
# 76751   46378  ZZ-0001       heliport            Sealand Helipad
# 76752  307326  ZZ-0002  small_airport  Glorioso Islands Airstrip
# 76753  346788  ZZ-0003  small_airport      Fainting Goat Airport
# 76754  342102     ZZZW         closed     Scandium City Heliport
# 76755  313629     ZZZZ  small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 0         40.070985     -74.933689          11.0       NaN          US
# ...

# %% [markdown]
# # Buscar aeropuertos españoles, agruparlos por tipo de puerto y contarlos
# Que aparezcan ordenados de forma descendente
# ficheros aeropuerto.csv

# %%
# Filtrar aeropuertos españoles po iso-countries
spain =aeropuerto[aeropuerto["iso_country"] == "ES"]
spain.head(5)
# Out:
#            id    ident           type                     name  latitude_deg  \
# 11198  300646      AEI       heliport       Algeciras Heliport     36.128820
# 23346   45168  ES-0001  small_airport       Trebujena Airfield     36.858889
# 23347  298473  ES-0002  small_airport         Vinaròs Airfield     40.519722
# 23348  299646  ES-0003       heliport  Banco de España Helipad     40.417913
# 23349  299647  ES-0004       heliport      Huerta Otea Helipad     40.964462
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 11198      -5.441079          98.0        EU          ES      ES-AN
# 23346      -6.139167          12.0        EU          ES      ES-AN
# 23347       0.390278         364.0        EU          ES      ES-VC
# 23348      -3.694920           NaN        EU          ES      ES-MD
# 23349      -5.683687           NaN        EU          ES      ES-CL
#
#       municipality scheduled_service gps_code iata_code local_code  \
# ...

# %%
result = spain.groupby(["type"]).count()["id"] 
result
# Out:
# type
# balloonport         1
# closed             28
# heliport          119
# large_airport      11
# medium_airport     43
# seaplane_base       1
# small_airport     309
# Name: id, dtype: int64

# %%
result.sort_values(ascending = False) #ordenamos de forma descendente
# Out:
# type
# small_airport     309
# heliport          119
# medium_airport     43
# closed             28
# large_airport      11
# balloonport         1
# seaplane_base       1
# Name: id, dtype: int64

# %%
spain =(aeropuerto[aeropuerto["iso_country"] == "ES"].groupby(["type"]).count()["id"].spain =aeropuerto[aeropuerto["iso_country"] == "ES"].groupby(["type"]).count()["id"].sort_values(ascending = False))
spain
# Out:
#   Cell In[75], line 1
#     spain =(aeropuerto[aeropuerto["iso_country"] == "ES"].groupby(["type"]).count()["id"].
#             ^
# SyntaxError: cannot assign to attribute here. Maybe you meant '==' instead of '='?

# %%
merged_data = pd.merge(aeropuerto,countries, left_on= "iso_country",right_on= "code", how="inner")
merged_data.info()

large_airports = merged_data[merged_data["type"] == "large_airport"]
large_airports
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76756 entries, 0 to 76755
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_x               76756 non-null  int64
#  1   ident              76756 non-null  object
#  2   type               76756 non-null  object
#  3   name_x             76756 non-null  object
#  4   latitude_deg       76756 non-null  float64
#  5   longitude_deg      76756 non-null  float64
#  6   elevation_ft       62397 non-null  float64
#  7   continent_x        39710 non-null  object
#  8   iso_country        76497 non-null  object
#  9   iso_region         76756 non-null  object
#  10  municipality       71805 non-null  object
#  11  scheduled_service  76756 non-null  object
#  12  gps_code           41615 non-null  object
#  13  iata_code          8898 non-null   object
#  14  local_code         32832 non-null  object
#  15  home_link          3711 non-null   object
# ...

# %%
(large_airports.groupby("name_y")["id_x"].
     count().sort_values (ascending = False).
     head(5))
# Out:
# name_y
# United States    67
# China            39
# Mexico           16
# Russia           16
# Italy            14
# Name: id_x, dtype: int64
